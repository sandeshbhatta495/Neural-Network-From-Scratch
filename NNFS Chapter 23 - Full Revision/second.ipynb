# %%
import numpy as np

class Layer_Dense:

    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))

    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases

# %%
# code Explaination of above code:
# 1. We define a class called Layer_Dense, which represents a dense layer in
# __init__ = weight initilization 
# self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
## We initialize the weights of the layer using a small random value multiplied by 0.01. The weights are generated using a normal distribution (randn) with dimensions (n_inputs, n_neurons).
## This means that each neuron in the layer will have a weight for each input feature. The  weights are stored in the self.weights attribute of the class.
# self.biases = np.zeros((1, n_neurons))
