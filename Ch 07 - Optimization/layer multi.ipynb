# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Create model
# ----> 2 dense1 = Layer_Dense(2, 3) # first dense layer, 2 inputs
#       3 activation1 = Activation_ReLU()
#       4 dense2 = Layer_Dense(3, 3) # second dense layer, 3 inputs, 3 outputs
#
# NameError: name 'Layer_Dense' is not defined
