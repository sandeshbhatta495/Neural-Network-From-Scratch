# %%
import math
print(math.log(1.))
print(math.log(0.95))
print(math.log(0.9))
print(math.log(0.8))
print('...')
print(math.log(0.2))
print(math.log(0.1))
print(math.log(0.05))
print(math.log(0.01))
# Out:
# 0.0
# -0.05129329438755058
# -0.10536051565782628
# -0.2231435513142097
# ...
# -1.6094379124341003
# -2.3025850929940455
# -2.995732273553991
# -4.605170185988091

# %%
import numpy as np
b = 5.2
print(np.log(b))
# Out:
# 1.6486586255873816

# %%
import math
print(math.e ** 1.6486586255873816)
# Out:
# 5.199999999999999

# %%
import numpy as np
np.mean([1, 2, 3, -np.log(0)])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10120\2360580745.py:2: RuntimeWarning: divide by zero encountered in log
#   np.mean([1, 2, 3, -np.log(0)])
# np.float64(inf)
